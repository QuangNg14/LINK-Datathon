# %%
import pandas as pd

# %%
vaccineByCounty = pd.read_excel("COVID-19 Vaccine Data by County.xlsx", sheet_name = "By County")

# %%
vaccineByCounty.head()
# Out:
#                                   County Name Public Health Region (PHR)  \
# 0                                       Texas                         --
# 1  Federal Long-Term Care Vaccination Program                         --
# 2                                    Anderson                       4/5N
# 3                                     Andrews                       9/10
# 4                                    Angelina                       4/5N
#
#    Total Doses Allocated Vaccine Doses Administered  \
# 0                4468600                    2755737
# 1                 720525                         --
# 2                   6200                       2525
# 3                   1600                       2559
# 4                  13600                       8427
#
#   People Vaccinated with at least One Dose People Fully Vaccinated  \
# 0                                  2136285                  619452
# 1                                       --                      --
# 2                                     2192                     333
# 3                                     1948                     611
# 4                                     6384                    2043
#
#   Population, 16+ Population, 65+ Population, Phase 1A Healthcare Workers  \
# 0        21407691         3329659                                 1241763
# 1              --              --                                      --
# 2           47597            8202                                    2051
# 3           12825            1801                                     309
# 4           67453           13539                                    6534
#
#   Population, Phase 1A Long-term Care Residents  \
# 0                                        271813
# 1                                            --
# 2                                           833
# 3                                           106
# 4                                          1752
#
#   Population, 16-64\n Any Medical Condition
# 0                                   8051352
# 1                                        --
# 2                                     20210
# 3                                      5148
# 4                                     28736

# %%
covidByCases = pd.read_excel("CaseCountData.xlsx", names = ["County", "Confirmed Cases", "Probable Cases", "Fatalities"], sheet_name = "Case and Fatalities")
x = pd.DataFrame(covidByCases)
x = x.drop([0, 1])
x.reset_index(drop=True)
# Out:
#        County Confirmed Cases Probable Cases Fatalities
# 0    Anderson            4763           1203         92
# 1     Andrews            1672              0         44
# 2    Angelina            4467           3059        229
# 3     Aransas             786            270         31
# 4      Archer             661             92         11
# ..        ...             ...            ...        ...
# 253    Zavala            1482            142         32
# 254   Unknown               0              0         17
# 255     Total         2143353         319533      38128
# 256   Unknown               0              0          .
# 257   Unknown               0              0          .
#
# [258 rows x 4 columns]
